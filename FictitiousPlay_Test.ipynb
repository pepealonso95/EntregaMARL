# %% [markdown]
# # Sanity check para FictitiousPlay Agent
# Este notebook prueba la implementación del FictitiousPlay Agent en todos los juegos disponibles durante al menos 10 episodios cada uno.

# %%
import numpy as np
import matplotlib.pyplot as plt

from games.rps import RPS
from games.mp import MP
from games.blotto import Blotto
from games.foraging import Foraging
from agents.fictitiousplay_t import FictitiousPlay # Import modificado

# %% [markdown]
# ## Definir juegos y configuraciones
# Define los juegos a probar y sus configuraciones.

# %%
games_to_test = [
    {"name": "RPS", "game": RPS, "config": {}},
    {"name": "MP", "game": MP, "config": {}},
    {"name": "Blotto", "game": Blotto, "config": {"S": 3, "N": 2}},
    {"name": "Foraging", "game": Foraging, "config": {"config": "Foraging-5x5-2p-1f-v3", "seed": 1}},
]

def get_game_instance(game_entry):
    if game_entry["name"] == "Blotto":
        return game_entry["game"](**game_entry["config"])
    elif game_entry["name"] == "Foraging":
        return game_entry["game"](config=game_entry["config"]["config"], seed=game_entry["config"]["seed"])
    else:
        return game_entry["game"]()

# %% [markdown]
# ## Inicializar FictitiousPlay Agent para cada juego
# Para cada juego, inicializar el FictitiousPlay Agent para todos los agentes en el entorno.

# %%
def create_agents(game):
    return {
        agent_id: FictitiousPlay(
            game=game, 
            agent=agent_id, 
            seed=1
        ) for agent_id in game.agents
    }

# %% [markdown]
# ## Ejecutar episodios para cada juego
# Ejecutar al menos 10 episodios por juego y recolectar las recompensas acumuladas.

# %%
def play_episodes(game, agents, episodes=10):
    recompensas_acumuladas_totales = {agent_id: 0.0 for agent_id in game.agents}
    game_name_for_debug = "UnknownGame"
    if hasattr(game, 'metadata') and game.metadata and 'name' in game.metadata:
        game_name_for_debug = game.metadata['name']
    elif hasattr(game, 'env') and hasattr(game.env, 'spec') and game.env.spec:
         game_name_for_debug = game.env.spec.id
    else:
        game_name_for_debug = game.__class__.__name__

    is_foraging_game = "Foraging" in game_name_for_debug

    for ep in range(episodes):
        if is_foraging_game:
            print(f"[Foraging Debug - FP] Starting Episode {ep+1}/{episodes} for {game_name_for_debug}")
        
        game.reset()

        turn = 0
        max_turns_per_episode = 200 

        while not (all(game.terminations.values()) or all(game.truncations.values())):
            if is_foraging_game:
                print(f"\n[Foraging Debug - FP] Episode {ep+1}, Turn {turn+1}")

            current_actions = {}
            for agent_id in game.agents:
                if not game.terminations[agent_id] and not game.truncations[agent_id]:
                    try:
                        action = agents[agent_id].action()
                        current_actions[agent_id] = action
                        if is_foraging_game:
                            print(f"[Foraging Debug - FP] Agent {agent_id} chose action: {action}")
                    except Exception as e:
                        if is_foraging_game:
                            print(f"[Foraging Debug - FP] ERROR in agent {agent_id}.action(): {e}")
                        import traceback
                        traceback.print_exc()
                        raise 
            
            if not current_actions:
                 if is_foraging_game:
                    print(f"[Foraging Debug - FP] All agents terminated/truncated. Ending episode.")
                 break

            try:
                game.step(current_actions) 
            except Exception as e:
                if is_foraging_game:
                    print(f"[Foraging Debug - FP] ERROR in game.step({current_actions}): {e}")
                import traceback
                traceback.print_exc()
                raise 

            for agent_id in game.agents:
                if not game.terminations[agent_id] and not game.truncations[agent_id]:
                    agents[agent_id].update() 
                recompensas_acumuladas_totales[agent_id] += game.reward(agent_id)
            
            if is_foraging_game:
                current_rewards = {ag: game.rewards[ag] for ag in game.agents}
                print(f"[Foraging Debug - FP] Rewards after turn {turn+1}: {current_rewards}")
                print(f"[Foraging Debug - FP] Terminations: {game.terminations}")
                print(f"[Foraging Debug - FP] Truncations: {game.truncations}")

            turn += 1
            if turn >= max_turns_per_episode: 
                if is_foraging_game:
                    print(f"[Foraging Debug - FP] Safety break: Exceeded {max_turns_per_episode} turns in episode {ep+1}.")
                for agent_id in game.agents:
                    game.truncations[agent_id] = True 
                break
        
        if is_foraging_game:
            print(f"[Foraging Debug - FP] Episode {ep+1} finished. Total turns: {turn}")

    return recompensas_acumuladas_totales

# %% [markdown]
# ## Mostrar resultados
# Mostrar las recompensas acumuladas para cada agente en cada juego después de 10 episodios.

# %%
resultados = {}
for entry in games_to_test:
    print(f"\nTesting {entry['name']} with FictitiousPlay Agent...")
    game_instance = get_game_instance(entry)
    agents = create_agents(game_instance)
    
    try:
        recompensas = play_episodes(game_instance, agents, episodes=10)
        resultados[entry['name']] = recompensas
        for agent, recompensa in recompensas.items():
            print(f"Agent {agent}: Total reward in 10 episodes: {recompensa}")
    except Exception as e:
        print(f"ERROR testing {entry['name']}: {e}")
        import traceback
        traceback.print_exc()
        resultados[entry['name']] = f"Error: {e}"

print("\n\nSummary of Results:")
for game_name, res in resultados.items():
    print(f"Game: {game_name}")
    if isinstance(res, dict):
        for agent, reward in res.items():
            print(f"  {agent}: {reward}")
    else:
        print(f"  Result: {res}")
# Out:
# Testing RPS with FictitiousPlay Agent...
# Agent agent_0: Total reward in 10 episodes: -1.0
# Agent agent_1: Total reward in 10 episodes: 1.0
#
# Testing MP with FictitiousPlay Agent...
# Agent agent_0: Total reward in 10 episodes: 0.0
# Agent agent_1: Total reward in 10 episodes: 0.0
#
# Testing Blotto with FictitiousPlay Agent...
# Agent agent_0: Total reward in 10 episodes: 0.0
# Agent agent_1: Total reward in 10 episodes: 0.0
#
# Testing Foraging with FictitiousPlay Agent...
# [Foraging Debug - FP] Starting Episode 1/10 for Foraging-5x5-2p-1f-v3
#
# [Foraging Debug - FP] Episode 1, Turn 1
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 1: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 2
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 2: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 3
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 3: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 4
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 4: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 5
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 5: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 6
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 6: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 7
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 7: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 8
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 8: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 9
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 9: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 10
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 10: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 11
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 11: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 12
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 12: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 13
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 13: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 14
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 14: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 15
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 15: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 16
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 16: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 17
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 17: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 18
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 18: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 19
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 19: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 20
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 20: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 21
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 21: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 22
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 22: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 23
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 23: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 24
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 24: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 25
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 25: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 26
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 26: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 27
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 27: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 28
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 28: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 29
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 29: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 30
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 30: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 31
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 31: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 32
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 32: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 33
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 33: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 34
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 34: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 35
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 35: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 36
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 36: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 37
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 37: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 38
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 38: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 39
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 39: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 40
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 40: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 41
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 41: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 42
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 42: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 43
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 43: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 44
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 44: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 45
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 45: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 46
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 46: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 47
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 47: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 1, Turn 48
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 48: {'agent_0': 1.0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': np.True_, 'agent_1': np.True_}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Episode 1 finished. Total turns: 48
# [Foraging Debug - FP] Starting Episode 2/10 for Foraging-5x5-2p-1f-v3
#
# [Foraging Debug - FP] Episode 2, Turn 1
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 1: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 2
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 2: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 3
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 3: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 4
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 4: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 5
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 5: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 6
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 6: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 7
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 7: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 8
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 8: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 9
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 9: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 10
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 10: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 11
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 11: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 12
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 12: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 13
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 13: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 14
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 14: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 15
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 15: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 16
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 16: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 17
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 17: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 18
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 18: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 19
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 19: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 20
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 20: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 21
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 21: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 22
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 22: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 23
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 23: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 24
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 24: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 25
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 25: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 26
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 26: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 27
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 27: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 28
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 28: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 29
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 29: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 30
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 30: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 31
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 31: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 32
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 32: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 33
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 33: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 34
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 34: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 35
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 35: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 36
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 36: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 37
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 37: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 38
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 38: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 39
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 39: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 40
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 40: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 41
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 41: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 42
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 42: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 43
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 43: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 44
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 44: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 45
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 45: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 46
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 46: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 47
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 47: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 48
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 48: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 49
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 49: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 2, Turn 50
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 50: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': True, 'agent_1': True}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Episode 2 finished. Total turns: 50
# [Foraging Debug - FP] Starting Episode 3/10 for Foraging-5x5-2p-1f-v3
#
# [Foraging Debug - FP] Episode 3, Turn 1
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 1: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 3, Turn 2
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 2: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 3, Turn 3
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 3: {'agent_0': 1.0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': np.True_, 'agent_1': np.True_}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Episode 3 finished. Total turns: 3
# [Foraging Debug - FP] Starting Episode 4/10 for Foraging-5x5-2p-1f-v3
#
# [Foraging Debug - FP] Episode 4, Turn 1
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 1: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 4, Turn 2
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 2: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 4, Turn 3
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 3: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 4, Turn 4
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 4: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 4, Turn 5
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 5: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 4, Turn 6
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 6: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 4, Turn 7
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 7: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 4, Turn 8
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 8: {'agent_0': 0, 'agent_1': 1.0}
# [Foraging Debug - FP] Terminations: {'agent_0': np.True_, 'agent_1': np.True_}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Episode 4 finished. Total turns: 8
# [Foraging Debug - FP] Starting Episode 5/10 for Foraging-5x5-2p-1f-v3
#
# [Foraging Debug - FP] Episode 5, Turn 1
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 1: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 5, Turn 2
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 2: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 5, Turn 3
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 3: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 5, Turn 4
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 4: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 5, Turn 5
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 5: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 5, Turn 6
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 6: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 5, Turn 7
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 7: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 5, Turn 8
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 8: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 5, Turn 9
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 9: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 5, Turn 10
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 10: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 5, Turn 11
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 11: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 5, Turn 12
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 12: {'agent_0': 1.0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': np.True_, 'agent_1': np.True_}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Episode 5 finished. Total turns: 12
# [Foraging Debug - FP] Starting Episode 6/10 for Foraging-5x5-2p-1f-v3
#
# [Foraging Debug - FP] Episode 6, Turn 1
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 1: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 6, Turn 2
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 2: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 6, Turn 3
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 3: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 6, Turn 4
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 4: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 6, Turn 5
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 5: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 6, Turn 6
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 6: {'agent_0': 1.0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': np.True_, 'agent_1': np.True_}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Episode 6 finished. Total turns: 6
# [Foraging Debug - FP] Starting Episode 7/10 for Foraging-5x5-2p-1f-v3
#
# [Foraging Debug - FP] Episode 7, Turn 1
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 1: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# ...
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 15: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 16
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 16: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 17
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 17: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 18
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 18: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 19
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 19: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 20
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 20: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 21
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 21: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 22
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 22: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 23
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 23: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 24
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 24: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 25
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 25: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 26
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 26: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 27
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 27: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 28
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 28: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 29
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 29: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 30
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 30: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 31
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 1
# [Foraging Debug - FP] Rewards after turn 31: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 32
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 32: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 33
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 33: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 34
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 34: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 35
# [Foraging Debug - FP] Agent agent_0 chose action: 1
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 35: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 36
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 36: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 37
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 37: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 38
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 38: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 39
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 39: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 40
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 40: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 41
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 41: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 42
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 5
# [Foraging Debug - FP] Rewards after turn 42: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 43
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 2
# [Foraging Debug - FP] Rewards after turn 43: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 44
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 44: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 45
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 45: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 46
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 46: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 47
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 47: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 48
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 48: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 49
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 49: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 50
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 50: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': True, 'agent_1': True}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Episode 10 finished. Total turns: 50
# Agent agent_0: Total reward in 10 episodes: 5.0
# Agent agent_1: Total reward in 10 episodes: 2.0
#
#
# Summary of Results:
# Game: RPS
#   agent_0: -1.0
#   agent_1: 1.0
# Game: MP
#   agent_0: 0.0
#   agent_1: 0.0
# Game: Blotto
#   agent_0: 0.0
#   agent_1: 0.0
# Game: Foraging
#   agent_0: 5.0
#   agent_1: 2.0
# [Foraging Debug - FP] Agent agent_0 chose action: 2
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 45: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 46
# [Foraging Debug - FP] Agent agent_0 chose action: 5
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 46: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 47
# [Foraging Debug - FP] Agent agent_0 chose action: 0
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 47: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 48
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 4
# [Foraging Debug - FP] Rewards after turn 48: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 49
# [Foraging Debug - FP] Agent agent_0 chose action: 3
# [Foraging Debug - FP] Agent agent_1 chose action: 3
# [Foraging Debug - FP] Rewards after turn 49: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
#
# [Foraging Debug - FP] Episode 10, Turn 50
# [Foraging Debug - FP] Agent agent_0 chose action: 4
# [Foraging Debug - FP] Agent agent_1 chose action: 0
# [Foraging Debug - FP] Rewards after turn 50: {'agent_0': 0, 'agent_1': 0}
# [Foraging Debug - FP] Terminations: {'agent_0': True, 'agent_1': True}
# [Foraging Debug - FP] Truncations: {'agent_0': False, 'agent_1': False}
# [Foraging Debug - FP] Episode 10 finished. Total turns: 50
# Agent agent_0: Total reward in 10 episodes: 5.0
# Agent agent_1: Total reward in 10 episodes: 2.0
#
#
# Summary of Results:
# Game: RPS
#   agent_0: -1.0
#   agent_1: 1.0
# Game: MP
#   agent_0: 0.0
#   agent_1: 0.0
# Game: Blotto
#   agent_0: 0.0
#   agent_1: 0.0
# Game: Foraging
#   agent_0: 5.0
#   agent_1: 2.0
